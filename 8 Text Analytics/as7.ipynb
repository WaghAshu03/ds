# %% [markdown]
# # installing nltk,punkt

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in c:\users\jayba\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\jayba\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in c:\users\jayba\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\jayba\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.5.4)
# Requirement already satisfied: tqdm in c:\users\jayba\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\jayba\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jayba\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # sentence tokenization

# %%
import nltk
from nltk.tokenize import sent_tokenize

text="""Hello Mr. Sumith, how are you doing today? The weather is great, and city is awsome.
The sky is pinkish-blue. You shouldn't eat cardboard"""

tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello Mr. Sumith, how are you doing today?', 'The weather is great, and city is awsome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard"]

# %% [markdown]
# # Word tokenize

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr.', 'Sumith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awsome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard']

# %% [markdown]
# # Frequency Tokenization

# %%
from nltk.probability import FreqDist
fdist=FreqDist(tokenized_word)
fdist
fdist.most_common(3)
# Out:
# [('is', 3), (',', 2), ('The', 2)]

# %%
import matplotlib.pyplot as plt
fdist.plot()
plt.show()

# %% [markdown]
# # stemming & Lexicon Normalization

# %%
# stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize,word_tokenize

ps=PorterStemmer()
s='fishing','fished','fisher','fish'
ps.stem(s[0])
# Out:
# 'fish'

# %% [markdown]
# # lemmatization

# %%
word='playing'

import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
wnl=WordNetLemmatizer()
print(wnl.lemmatize(word,'n'))
print(wnl.lemmatize(word,'v'))
print(wnl.lemmatize(word,'a'))
print(wnl.lemmatize(word,'r'))
# Out:
# playing
# play
# playing
# playing
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\jayba\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # POS tagging

# %%
import nltk 
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\jayba\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
sents="Rajgad (literal meaning Ruling Fort) is a hill fort situated in Pune district"

# %%
words=word_tokenize(sents)
words
# Out:
# ['Rajgad',
#  '(',
#  'literal',
#  'meaning',
#  'Ruling',
#  'Fort',
#  ')',
#  'is',
#  'a',
#  'hill',
#  'fort',
#  'situated',
#  'in',
#  'Pune',
#  'district']

# %%
nltk.download('omw-1.4')
nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\jayba\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [('Rajgad', 'NNP'),
#  ('(', '('),
#  ('literal', 'JJ'),
#  ('meaning', 'NN'),
#  ('Ruling', 'NNP'),
#  ('Fort', 'NNP'),
#  (')', ')'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('hill', 'NN'),
#  ('fort', 'NN'),
#  ('situated', 'VBD'),
#  ('in', 'IN'),
#  ('Pune', 'NNP'),
#  ('district', 'NN')]
