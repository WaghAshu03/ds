# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class
# 0         0       3    male  22.0      1      0   7.2500        S  Third  \
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Distributed plot

sns.distplot(x=df['age'],bins=10)
# Out:
# C:\Users\Ashu\AppData\Local\Temp\ipykernel_18076\2388288210.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['age'],bins=10)
# <Axes: ylabel='Density'>

# %%
# Histogram
sns.histplot(x=df['age'],bins=10,kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
# Joint PLot & Bar Plot
# plot 1
sns.jointplot(x=df['age'],y=df['fare'],kind='scatter')

# %%
# plot 2
sns.jointplot(x=df['age'],y=df['fare'],kind='hex')

# %%
# bar plot
sns.barplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x=df['sex'],y=df['age'],estimator=np.std)
# Out:
# c:\Users\Ashu\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\lib\nanfunctions.py:1559: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a,
# <Axes: xlabel='sex', ylabel='age'>

# %%
# count plot
sns.countplot(x=df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# box plot
sns.boxplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.boxplot(x=df['sex'],y=df['age'],hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# violin plot
sns.violinplot(x=df['sex'],y=df['age'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x=df['sex'],y=df['age'],hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# strip plot
sns.stripplot(x=df['sex'],y=df['age'],jitter=True,hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.stripplot(x=df['sex'],y=df['age'],jitter=False,hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# the swarm plot
sns.swarmplot(x=df['sex'],y=df['age'],hue=df['alive'])
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
# heat map
df_encoded = pd.get_dummies(df)
corr = df_encoded.corr()
corr
# Out:
#                          survived    pclass       age     sibsp     parch
# survived                 1.000000 -0.338481 -0.077221 -0.035322  0.081629  \
# pclass                  -0.338481  1.000000 -0.369226  0.083081  0.018443
# age                     -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# sibsp                   -0.035322  0.083081 -0.308247  1.000000  0.414838
# parch                    0.081629  0.018443 -0.189119  0.414838  1.000000
# fare                     0.257307 -0.549500  0.096067  0.159651  0.216225
# adult_male              -0.557080  0.094035  0.280328 -0.253586 -0.349943
# alone                   -0.203367  0.135207  0.198270 -0.584471 -0.583398
# sex_female               0.543351 -0.131900 -0.093254  0.114631  0.245489
# sex_male                -0.543351  0.131900  0.093254 -0.114631 -0.245489
# embarked_C               0.168240 -0.243292  0.036261 -0.059528 -0.011069
# embarked_Q               0.003650  0.221009 -0.022405 -0.026354 -0.081228
# embarked_S              -0.155660  0.081720 -0.032523  0.070941  0.063036
# class_First              0.285904 -0.885924  0.348941 -0.054582 -0.017633
# class_Second             0.093349 -0.188432  0.006954 -0.055932 -0.000734
# class_Third             -0.322308  0.916673 -0.312271  0.092548  0.015790
# who_child                0.136107  0.121920 -0.582875  0.352437  0.351481
# who_man                 -0.557080  0.094035  0.280328 -0.253586 -0.349943
# who_woman                0.506562 -0.177049  0.105081  0.047071  0.150167
# deck_A                   0.022287 -0.204934  0.136309 -0.046266 -0.040325
# deck_B                   0.175095 -0.369572  0.093914 -0.034538  0.056498
# deck_C                   0.114652 -0.417048  0.122041  0.029251  0.030736
#                          ...    deck_C    deck_D    deck_E    deck_F
# survived                 ...  0.114652  0.150716  0.145321  0.057935  \
# pclass                   ... -0.417048 -0.278690 -0.230091  0.011063
# age                      ...  0.122041  0.136975  0.121440 -0.083970
# sibsp                    ...  0.029251 -0.017575 -0.036865  0.001706
# parch                    ...  0.030736 -0.019125 -0.016554  0.023694
# fare                     ...  0.364318  0.098878  0.053717 -0.033093
# adult_male               ... -0.042050 -0.059374 -0.040505 -0.054228
# alone                    ... -0.125062 -0.083664 -0.028179 -0.015972
# sex_female               ...  0.058649  0.079248  0.047003  0.008202
# sex_male                 ... -0.058649 -0.079248 -0.047003 -0.008202
# embarked_C               ...  0.113952  0.102977 -0.015939 -0.034726
# embarked_Q               ... -0.049776 -0.060318 -0.037897 -0.004113
# embarked_S               ... -0.066995 -0.051139  0.038685  0.033537
# class_First              ...  0.470749  0.291218  0.242675 -0.068833
# class_Second             ... -0.135851 -0.041325 -0.038864  0.122906
# class_Third              ... -0.295036 -0.217282 -0.177461 -0.040721
# who_child                ... -0.054291 -0.062856 -0.041108  0.089818
# who_man                  ... -0.042050 -0.059374 -0.040505 -0.054228
# who_woman                ...  0.079027  0.102866  0.069056  0.000936
# deck_A                   ... -0.034846 -0.025663 -0.025256 -0.015923
# deck_B                   ... -0.062841 -0.046280 -0.045547 -0.028715
# deck_C                   ...  1.000000 -0.052225 -0.051398 -0.032403
# deck_D                   ... -0.052225  1.000000 -0.037852 -0.023864
# deck_E                   ... -0.051398 -0.037852  1.000000 -0.023486
# deck_F                   ... -0.032403 -0.023864 -0.023486  1.000000
# deck_G                   ... -0.017883 -0.013170 -0.012961 -0.008171
# embark_town_Cherbourg    ...  0.113952  0.102977 -0.015939 -0.034726
# embark_town_Queenstown   ... -0.049776 -0.060318 -0.037897 -0.004113
# embark_town_Southampton  ... -0.066995 -0.051139  0.038685  0.033537
# alive_no                 ... -0.114652 -0.150716 -0.145321 -0.057935
# alive_yes                ...  0.114652  0.150716  0.145321  0.057935
#
#                            deck_G  embark_town_Cherbourg
# survived                 0.016040               0.168240  \
# pclass                   0.055561              -0.243292
# age                     -0.077296               0.036261
# sibsp                   -0.001402              -0.059528
# parch                    0.072388              -0.011069
# fare                    -0.025180               0.269335
# adult_male              -0.082709              -0.065980
# alone                   -0.082709              -0.095298
# sex_female               0.091031               0.082853
# sex_male                -0.091031              -0.082853
# embarked_C              -0.032371               1.000000
# embarked_Q              -0.020654              -0.148258
# embarked_S               0.041589              -0.778359
# class_First             -0.037988               0.296423
# class_Second            -0.034258              -0.125416
# class_Third              0.060612              -0.153329
# who_child                0.094001               0.023201
# who_man                 -0.082709              -0.065980
# who_woman                0.028588               0.055524
# deck_A                  -0.008787               0.093040
# deck_B                  -0.015847               0.168642
# deck_C                  -0.017883               0.113952
# deck_D                  -0.013170               0.102977
# deck_E                  -0.012961              -0.015939
# deck_F                  -0.008171              -0.034726
# deck_G                   1.000000              -0.032371
# embark_town_Cherbourg   -0.032371               1.000000
# embark_town_Queenstown  -0.020654              -0.148258
# embark_town_Southampton  0.041589              -0.778359
# alive_no                -0.016040              -0.168240
# alive_yes                0.016040               0.168240
#
#                          embark_town_Queenstown  embark_town_Southampton
# survived                               0.003650                -0.155660  \
# pclass                                 0.221009                 0.081720
# age                                   -0.022405                -0.032523
# sibsp                                 -0.026354                 0.070941
# parch                                 -0.081228                 0.063036
# fare                                  -0.117216                -0.166603
# adult_male                            -0.076789                 0.112035
# alone                                  0.086464                 0.024929
# sex_female                             0.074115                -0.125722
# sex_male                              -0.074115                 0.125722
# embarked_C                            -0.148258                -0.778359
# embarked_Q                             1.000000                -0.496624
# embarked_S                            -0.496624                 1.000000
# class_First                           -0.155342                -0.170379
# class_Second                          -0.127301                 0.192061
# class_Third                            0.237449                -0.009511
# who_child                             -0.029861                 0.000077
# who_man                               -0.076789                 0.112035
# who_woman                              0.100544                -0.119217
# deck_A                                -0.040246                -0.055383
# deck_B                                -0.072579                -0.123057
# deck_C                                -0.049776                -0.066995
# deck_D                                -0.060318                -0.051139
# deck_E                                -0.037897                 0.038685
# deck_F                                -0.004113                 0.033537
# deck_G                                -0.020654                 0.041589
# embark_town_Cherbourg                 -0.148258                -0.778359
# embark_town_Queenstown                 1.000000                -0.496624
# embark_town_Southampton               -0.496624                 1.000000
# alive_no                              -0.003650                 0.155660
# alive_yes                              0.003650                -0.155660
#
#                          alive_no  alive_yes
# survived                -1.000000   1.000000
# pclass                   0.338481  -0.338481
# age                      0.077221  -0.077221
# sibsp                    0.035322  -0.035322
# parch                   -0.081629   0.081629
# fare                    -0.257307   0.257307
# adult_male               0.557080  -0.557080
# alone                    0.203367  -0.203367
# sex_female              -0.543351   0.543351
# sex_male                 0.543351  -0.543351
# embarked_C              -0.168240   0.168240
# embarked_Q              -0.003650   0.003650
# embarked_S               0.155660  -0.155660
# class_First             -0.285904   0.285904
# class_Second            -0.093349   0.093349
# class_Third              0.322308  -0.322308
# who_child               -0.136107   0.136107
# who_man                  0.557080  -0.557080
# who_woman               -0.506562   0.506562
# deck_A                  -0.022287   0.022287
# deck_B                  -0.175095   0.175095
# deck_C                  -0.114652   0.114652
# deck_D                  -0.150716   0.150716
# deck_E                  -0.145321   0.145321
# deck_F                  -0.057935   0.057935
# deck_G                  -0.016040   0.016040
# embark_town_Cherbourg   -0.168240   0.168240
# embark_town_Queenstown  -0.003650   0.003650
# embark_town_Southampton  0.155660  -0.155660
# alive_no                 1.000000  -1.000000
# alive_yes               -1.000000   1.000000
#
# [31 rows x 31 columns]

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# Hist plot
sns.histplot(df['fare'],bins=10)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
